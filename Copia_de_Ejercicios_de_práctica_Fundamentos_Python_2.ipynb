# %% [markdown]
# ###**Ejercicios de práctica Fundamentos Python (2)**

# %% [markdown]
# ***Listas, tuplas y diccionarios***

# %% [markdown]
# **A. Listas**

# %% [markdown]
# **1.Crear una lista de notas**

# %%
notas = [1.0,3.5,4.5, 1.8,6.0]
print (len(notas))
print(notas)
# Out:
# 5
# [1.0, 3.5, 4.5, 1.8, 6.0]

# %% [markdown]
# **2.Acceder por índice**

# %%
temperaturas = [18, 20, 19, 21, 22]
print(temperaturas[0])
print(temperaturas[2])
print(temperaturas[4])
# Out:
# 18
# 19
# 22

# %% [markdown]
# **3.Actualizar un elemento**

# %%
ventas = [120, 80, 200, 50]
ventas [1]= 85
print(ventas)
# Out:
# [120, 85, 200, 50]

# %% [markdown]
# ***4.Agregar y extraer datos***

# %%
notas = [3.5, 4.0, 2.8]

notas.append(4.6)
ultima = notas.append(2.8)
print(ultima)
print(notas)
# Out:
# None
# [3.5, 4.0, 2.8, 4.6, 2.8]

# %% [markdown]
# ***5.Calcular promedio***

# %%
notas = [4.2, 3.8, 5.0, 2.9]
total = 0

for nota in notas:
  total =total + nota
  promedio =total /len (notas)
  print (round(promedio,2))
# Out:
# 1.05
# 2.0
# 3.25
# 3.98

# %% [markdown]
# ***6.Contar aprobados***

# %%
notas = [4.2, 2.5, 3.0, 1.8, 4.7]
aprobados = 0
for nota in notas:
    if nota >= 3.0:
        aprobados = aprobados + 1
print(aprobados)
# Out:
# 3

# %% [markdown]
# ***7.Filtrar valores válidos***

# %%
lecturas = [18, 200, 21, -99, 19, 22]
validas = [0]

for t in lecturas:
    if t >= -10 and t <= 50:
          validas.append(t)

print(validas)
# Out:
# [0, 18, 21, 19, 22]

# %% [markdown]
# ***8.Ordenar sin perder el original***

# %%
montos = [120000, 85000, 210000, 50000]
ordenados = sorted(montos)
print(montos)
print(ordenados)
# Out:
# [120000, 85000, 210000, 50000]
# [50000, 85000, 120000, 210000]

# %% [markdown]
# ***9.Comprensión de listas***

# %%
numeros = [1, 2, 3, 4, 5, 6]
cuadrados_pares = [n**2 for n in numeros if n % 2 == 0]
print(cuadrados_pares)
# Out:
# [4, 16, 36]

# %% [markdown]
# ***10.Lista anidada***

# %%
matriz = [[1, 2, 3], [4, 5, 6]]
total = 0
for fila in matriz:
  for valor in fila:
   total += valor
print(total)
# Out:
# 21

# %% [markdown]
# **B. Tuplas**

# %% [markdown]
# **11. Crear una tupla fija**

# %%
ubicacion = (5.2, 7.4)
print(ubicacion)
print(type(ubicacion))
# Out:
# (5.2, 7.4)
# <class 'tuple'>

# %% [markdown]
# **12.Desempaquetar una tupla**

# %%
registro = ("A01", "Laura", 4.6)
Codigo ,nombre ,nota = registro
print (nombre)
print (nota)
# Out:
# Laura
# 4.6

# %% [markdown]
# **13.Tupla de un solo elemento**

# %%
codigo = ("A01",)
print(codigo)
print(type(codigo))
# Out:
# ('A01',)
# <class 'tuple'>

# %% [markdown]
# **14.Convertir lista a tupla**

# %%
columnas = ["fecha", "monto", "cliente"]
columnas_fijas = len(columnas)
print(columnas_fijas)
# Out:
# 3

# %% [markdown]
# **15.Retorno múltiple**

# %%
def resumen(valores):
    menor = min(valores)
    mayor = max(valores)
    return 3,10

minimo, maximo = resumen([8, 3, 10, 5])
print(minimo, maximo)
# Out:
# 3 10

# %% [markdown]
# 16. Reconocer inmutabilidad

# %%
punto = (10, 20)
punto[0] = 99
print(punto)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_1042/541012934.py in <cell line: 0>()
#       1 punto = (10, 20)
# ----> 2 punto[0] = 99
#       3 print(punto)
#
# TypeError: 'tuple' object does not support item assignment

# %% [markdown]
#  **¿por qué esta restricción puede ser útil en un programa real?**
#
# Porque garantiza que ese dato no se cambie por accidente y Poder usarla como clave en un diccionario o en un set, las listas no permiten eso.

# %% [markdown]
# **17.Tupla como clave**

# %%
lecturas = {}
coordenada = (4.65, -74.05)
lecturas[coordenada] = 18.5
print(lecturas[(4.65, -74.05)])
# Out:
# 18.5

# %% [markdown]
# **18. Combinar listas con zip**

# %%
nombres = ["Ana", "Luis", "Marta"]
notas = [4.2, 3.8, 5.0]
pares = list(zip(nombres, notas))
print(pares)
# Out:
# [('Ana', 4.2), ('Luis', 3.8), ('Marta', 5.0)]

# %% [markdown]
# **C. Diccionarios**

# %% [markdown]
# **19. Crear un diccionario**

# %%
estudiante = {
    codigo: "A01",
    nombre: "Laura",
    nota: 4.6
}
print(estudiante)
# Out:
# {('A01',): 'A01', 'Laura': 'Laura', 4.6: 4.6}

# %%
def suma (a,b=10):
  return a+ b
x = suma(5)
y = suma(5,2)
z = suma(b=1,a=1)

print(x,y,z)
# Out:
# 15 7 2

# %% [markdown]
# **20 Acceso seguro con get()**

# %%
cliente = {"nombre": "Carlos", "puntaje": 720}
saldo = cliente.get("saldo", 0)
print(saldo)
# Out:
# 0

# %% [markdown]
# **21.Actualizar valores**

# %%
producto = {"codigo": "P01", "stock": 8}
producto["stock"] = producto["stock"] - 3
print(producto["stock"])
# Out:
# 5

# %% [markdown]
# **22.Recorrer pares clave-valor**

# %%
producto = {"codigo": "P01", "precio": 12000, "stock": 8}
for clave, valor in producto.items():
    print(clave, valor)
# Out:
# codigo P01
# precio 12000
# stock 8

# %% [markdown]
# **23.Contar por categoría**

# %%
tipos = ["Debito", "Credito", "Debito", "Debito", "Credito"]
conteo = {}
for tipo in tipos:
    conteo[tipo] = conteo.get(tipo, 0) + 1
print(conteo)
# Out:
# {'Debito': 3, 'Credito': 2}

# %% [markdown]
# **24.Diccionario anidado**

# %%
grupo = {
    "A01": {"nombre": "Laura", "nota": 4.6},
    "A02": {"nombre": "Luis", "nota": 3.8}
}
print(grupo["A01"]["nota"])
# Out:
# 4.6

# %% [markdown]
# **25. Lista de diccionarios**

# %%
transacciones = [
    {"id": "T01", "monto": 120000},
    {"id": "T02", "monto": 85000},
    {"id": "T03", "monto": 210000}
]
total = 0
for t in transacciones:
    total += t["monto"]
print(total)
# Out:
# 415000

# %% [markdown]
# **26.Buscar por código**

# %%
estudiantes = [
    {"codigo": "A01", "nombre": "Laura"},
    {"codigo": "A02", "nombre": "Luis"}
]
buscado = "A02"
resultado = None
for e in estudiantes:
    if e["codigo"] == buscado:
        resultado = e["nombre"]
print(resultado)
# Out:
# Luis

# %% [markdown]
# **27.Filtrar diccionarios**

# %%
estudiantes = [
    {"nombre": "Ana", "nota": 4.2},
    {"nombre": "Luis", "nota": 2.8},
    {"nombre": "Marta", "nota": 3.5}
]
aprobados = []
for e in estudiantes:
    if e["nota"] >= 3:
        aprobados.append(e["nombre"])
print(aprobados)
# Out:
# ['Ana', 'Marta']

# %% [markdown]
# **28.Agrupar por estado**

# %%
clientes = [
    {"nombre": "Ana", "riesgo": "bajo"},
    {"nombre": "Luis", "riesgo": "alto"},
    {"nombre": "Marta", "riesgo": "bajo"}
]
grupo = {}
for c in clientes:
    riesgo = c["riesgo"]
    if riesgo not in grupo:
        grupo[riesgo] = []
    grupo[riesgo].append(c["nombre"])
print(grupo)
# Out:
# {'bajo': ['Ana', 'Marta'], 'alto': ['Luis']}

# %% [markdown]
# **29.Inventario académico**

# %%
inventario = [
    {"producto": "Marcador", "stock": 4},
    {"producto": "Cuaderno", "stock": 20},
    {"producto": "Borrador", "stock": 2}
]
bajos = []
for item in inventario:
    if item["stock"] < 5:
        bajos.append(item["stock"])
print(bajos)
# Out:
# [4, 2]

# %% [markdown]
# ###Reto integrador

# %% [markdown]
# *Combina listas de diccionarios, filtros y acumuladores*

# %% [markdown]
# **30.Mini caso integrador**

# %%
transacciones = [
    {"cliente": "Ana", "tipo": "Credito", "monto": 120000},
    {"cliente": "Luis", "tipo": "Debito", "monto": 85000},
    {"cliente": "Marta", "tipo": "Credito", "monto": 210000}
]
total_creditos = 0
clientes = []
for t in transacciones:
    if t["tipo"] == "credito" and t["monto"] >= 100000:
        total_creditos += t["monto"]
        clientes.append(t["cliente"])
print(total_creditos)
print(clientes)
# Out:
# 0
# []

# %% [markdown]
# ###**Autoevaluación**

# %% [markdown]
# **1. ¿Puedo elegir entre lista, tupla y diccionario según el problema?**
#
# Lista []: Cuando el orden importa y vas a agregar / quitar.
#
# Tupla (): Cuando es un dato fijo que NO debe cambiar.
#
# Diccionario {}: Cuando necesitas clave -> valor.
#
#
# **2. ¿Puedo recorrer una colección y acumular un resultado?**
#
#
# SÍ. Patrón base de todo el módulo:
#
# **3. ¿Puedo filtrar registros dentro de una lista de diccionarios?**
#
# SÍ. Es lo que hicimos en los ejercicios 27, 29 y 30
#
# **4. ¿Puedo explicar por qué una tupla no admite asignación por índice?**
#
# protege que el dato no se corrompa, te permite usarla como clave
