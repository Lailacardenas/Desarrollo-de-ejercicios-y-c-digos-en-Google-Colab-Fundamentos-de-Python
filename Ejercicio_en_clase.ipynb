# %% [markdown]
# ## **Ejercicios en clase replicando codigo del PPTX compartido**

# %% [markdown]
# *En este notebook se replicara el codigo de la presentación del profesor en esta clase*

# %% [markdown]
# ##**Diapositiva 4** :Secuencia

# %%
precio = 1000000
iva = precio * 0.19
total = precio + iva

# %% [markdown]
# *El resultado obtenido indica que se logró aplicar correctamente el IVA del 19 % sobre el precio establecido y calcular el valor total de la compra.*

# %% [markdown]
# ###**Diapositiva 4** :Selección

# %%
if total > 100000 :
  print ("compra de alto valor ")
else :
  print ("compra de bajo valor ")
# Out:
# compra de alto valor

# %% [markdown]
# *El resultado obtenido permite comprobar que el programa evaluó correctamente la condición establecida para determinar si la compra corresponde a un valor alto o bajo*

# %% [markdown]
# ##**Diapositiva** 4 :Repeticón

# %%
for i  in range (5) :
  print (i)
# Out:
# 0
# 1
# 2
# 3
# 4

# %% [markdown]
# *El resultado obtenido muestra los números correspondientes a las cinco iteraciones establecidas*
